# %% [markdown]
# LeetCode 2520

# %% [markdown]
# https://leetcode.com/problems/count-the-digits-that-divide-a-number/

# %%
num = 121
if num <=9:
    print(1)
else:
    count = 0
    for s in str(num):
        if num % int(s) == 0:
            count += 1
    print(count)
# Out:
# 2
